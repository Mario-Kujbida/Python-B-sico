# %%
num_1 = 4
num_2 = 2
print(num_1 + num_2)
print(num_1 - num_2)
# Out:
# 6
# 2

# %%
tupla_1 = (1, 2, 3)
tupla_2 = (1, 2, 3)
print (tupla_1 + tupla_2)
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
tupla_1 += tupla_2
display(tupla_1)
display(tupla_2)
# Out:
# (1, 2, 3, 1, 2, 3)
# (1, 2, 3)

# %%
list(tupla_1)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
dict_1 = {"a": 1, "b": 2}
dict_2 = {"a": 10, "b": 20}
dict_1 + dict_2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 dict_1 = {"a": 1, "b": 2}
#       2 dict_2 = {"a": 10, "b": 20}
# ----> 3 dict_1 + dict_2
#
# TypeError: unsupported operand type(s) for +: 'dict' and 'dict'

# %%
lista_tupla_1 = list(tupla_1)
lista_tupla_1
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
lista_tupla_1 [2] += 2
lista_tupla_1
# Out:
# [1, 2, 35, 1, 2, 3]

# %%
import numpy as np

# %%
array = np.array(lista_tupla_1)
array
# Out:
# array([ 1,  2, 35,  1,  2,  3])

# %%
array += 2
array
# Out:
# array([ 3,  4, 37,  3,  4,  5])

# %%
array *= array
array
# Out:
# array([   9,   16, 1369,    9,   16,   25])

# %%
np.insert(arr=array, obj=2, values=100)
# Out:
# array([   9,   16,  100, 1369,    9,   16,   25])

# %%
array = np.array(lista_tupla_1).reshape(2, -1)
array
# Out:
# array([[ 1,  2, 35],
#        [ 1,  2,  3]])

# %%
import pandas as pd

# %%
df = pd.DataFrame(array)
df
# Out:
#    0  1   2
# 0  1  2  35
# 1  1  2   3

# %%
array_ones = np.ones_like(df).reshape(3,2)
array_ones [1,1] = 100
array_ones
# Out:
# array([[  1,   1],
#        [  1, 100],
#        [  1,   1]])

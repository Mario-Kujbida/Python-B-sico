# %% [markdown]
# # Exercício:

# %% [markdown]
# ## 01 – Quais as vantagens da utilização de objetos compostos em detrimento dos objetos simples?

# %% [markdown]
# R = Otimização de espaço (memória RAM), melhor controle de variáveis, reutilização dos dados, estruturação (organização) dos dados..

# %% [markdown]
# ## 02 – Instancie uma variável da classe tupla, contendo 5 valores de qualquer classe, e recupere os valores:

# %%
tupla = ("Mario", 13, 13.13, False)
tupla
# Out:
# ('Mario', 13, 13.13, False)

# %% [markdown]
# ## 03 – Instancie uma variável da classe lista, contendo 5 valores de qualquer classe, e recupere cada um dos valores:

# %%
lista = ["Roar", "Obsessed", 13, "Hello"]
print (lista [0])
print (lista [1])
print (lista [2])
print (lista [3])
# Out:
# Roar
# Obsessed
# 13
# Hello

# %% [markdown]
# ## 04 – Instancie uma variável da classe lista, contendo 5 nomes de genes diferentes, recupere de cada um dos valores quantas letras ‘a’ estão presentes:

# %%
lista_HDACS = ["HDAC1", "HDAC2", "HDAC3", "HDAC4", "HDAC5"]
print (lista_HDACS[0].count ("A"))
print (lista_HDACS[1].count ("A"))
print (lista_HDACS[2].count ("A"))
print (lista_HDACS[3].count ("A"))
print (lista_HDACS[4].count ("A"))
# Out:
# 1
# 1
# 1
# 1
# 1

# %% [markdown]
# ## 05 – Instancie uma variável da classe lista, contendo 5 valores, e recupere do segundo ao quarto valores:

# %%
lista_VALORES = [13, 22, 10, 19, 97]
print (lista_VALORES [1:4])
# Out:
# [22, 10, 19]

# %% [markdown]
# ## 06 – Instancie uma variável da classe string com o seu nome como valor, e recupere o segundo e o último valores:

# %%
nome = "m", "a", "r", "i", "o"
print (nome[1])
print (nome [-1])
# Out:
# a
# o

# %% [markdown]
# ## 07 – Instancie uma variável da classe dicionário com quantos valores inteiros desejar. Usando as funções globais, retorne a classe do objeto, quantos valores estão instanciados e a soma dos valores contidos no objeto:

# %%
 dicionario = {"mario": 666, "antonio": 13, "kujbida": 24, "junior": 69}
 print (type (dicionario))
 print (type (dicionario["mario"]))
 print (len (dicionario))
 print (sum (dicionario.values()))
# Out:
# <class 'dict'>
# <class 'int'>
# 4
# 772

# %% [markdown]
# ## 08 – Instancie uma variável da classe dicionário. Os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes de genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser o número de caracteres em cada index. Retorne o objeto:

# %%
# para a lista (for), e cada de cada gene nessa lsita (in), vai ser feita o valor de cada um (len)#
dicionario_2 = {lista_HDACS: len(lista_HDACS) for lista_HDACS in lista_HDACS}
dicionario_2
# Out:
# {'HDAC1': 5, 'HDAC2': 5, 'HDAC3': 5, 'HDAC4': 5, 'HDAC5': 5}

# %% [markdown]
# ## 09 – Instancie cinco variáveis da classe lista. Cada uma delas será referente à um dos valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Em cada uma das listas, você deve inserir o número de caracteres presentes no nome do gene, os dois primeiros caracteres do nome, quantas vezes aparece o caractere ‘a’ e se no nome aparecem os caracteres ‘hu’. Para isso você deve utilizar a indexação de lista. Retorne cada um dos objetos:

# %%
lista_HDAC1 = [
    len(lista_HDACS[0]), 
    lista_HDACS [0] [:2], 
    lista_HDACS [0].count ("A"), 
    "hu" in lista_HDACS [0]
]
print (lista_HDAC1)
# Out:
# [5, 'HD', 1, False]

# %%
lista_HDAC2 = [
    len(lista_HDACS[1]), 
    lista_HDACS [1] [:2], 
    lista_HDACS [1].count ("A"), 
    "hu" in lista_HDACS [1]
]
print (lista_HDAC2)
# Out:
# [5, 'HD', 1, False]

# %%
lista_HDAC3 = [
    len(lista_HDACS[2]), 
    lista_HDACS [2] [:2], 
    lista_HDACS [2].count ("A"), 
    "hu" in lista_HDACS [2]
]
print (lista_HDAC3)
# Out:
# [5, 'HD', 1, False]

# %%
lista_HDAC4 = [
    len(lista_HDACS[3]), 
    lista_HDACS [3] [:2], 
    lista_HDACS [3].count ("A"), 
    "hu" in lista_HDACS [3]
]
print (lista_HDAC4)
# Out:
# [5, 'HD', 1, False]

# %%
lista_HDAC5 = [
    len(lista_HDACS[4]), 
    lista_HDACS [4] [:2], 
    lista_HDACS [4].count ("A"), 
    "hu" in lista_HDACS [4]
]
print (lista_HDAC5)
# Out:
# [5, 'HD', 1, False]

# %% [markdown]
# ## 10 – Instancie uma variável da classe dicionário, os index dos valores devem ser os valores contidos na lista instanciada no exercício 4 (Nomes dos genes). Para isso você deve utilizar a indexação de lista. Os valores devem ser as listas instanciadas no exercício 9. Retorne o objeto.

# %%
dicionario_HDACS = {
    lista_HDACS[0]:lista_HDAC1,
    lista_HDACS[1]:lista_HDAC2,
    lista_HDACS[2]:lista_HDAC3,
    lista_HDACS[3]:lista_HDAC4,
    lista_HDACS[4]:lista_HDAC5
}
print (dicionario_HDACS)
# Out:
# {'HDAC1': [5, 'HD', 1, False], 'HDAC2': [5, 'HD', 1, False], 'HDAC3': [5, 'HD', 1, False], 'HDAC4': [5, 'HD', 1, False], 'HDAC5': [5, 'HD', 1, False]}

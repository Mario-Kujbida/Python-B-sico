# %%
import pandas as pd
import numpy as np

# %%
array = np.random.normal(20, 2.5, 40)
array
# Out:
# array([23.93249616, 21.21098976, 19.19012227, 19.53889529, 18.56045263,
#        22.31734365, 18.51868251, 23.87099679, 18.3866078 , 20.58277257,
#        15.27501496, 17.19202196, 16.98441957, 19.14726392, 20.71314793,
#        18.39442389, 24.48017977, 23.29895143, 22.16238259, 17.40584305,
#        19.73673703, 17.98027467, 21.12395766, 23.63138271, 25.65530908,
#        22.02471367, 17.58125395, 23.43324224, 19.13679155, 22.41905924,
#        23.94813214, 22.40476465, 17.82702981, 27.03414927, 21.69414072,
#        16.30512901, 19.89209695, 16.3888012 , 23.99204984, 19.67052358])

# %%
array = np.random.normal(20, 2.5, 40).reshape(8,5)
array
# Out:
# array([[20.70753391, 17.36026279, 22.56459453, 20.49417487, 20.64658912],
#        [20.44782125, 18.83393009, 16.70362389, 20.26854926, 18.48708733],
#        [15.36641849, 23.71539609, 20.95089592, 17.26855368, 21.37493622],
#        [22.00879435, 16.17428303, 21.42964776, 21.15038526, 17.66983046],
#        [21.35378582, 21.16090348, 18.49192873, 23.00904395, 16.10634557],
#        [20.94407827, 23.65924965, 19.47272539, 18.18904334, 22.51368147],
#        [18.14640979, 20.69525083, 19.77506492, 20.59379197, 17.02042005],
#        [19.03258983, 22.51682986, 17.35035753, 17.69847011, 20.67891752]])

# %%
if array[3,1] >= 200:
    resposta = 'O VALOR É MAIOR OU IGUAL A 200'
else:
    resposta = 'O VALOR NÃO É MAIOR OU IGUAL A 200'
resposta
# Out:
# 'O VALOR NÃO É MAIOR OU IGUAL A 200'

# %%
if array[3,1] >= 200:
    resposta = 'O VALOR É MAIOR OU IGUAL A 200'
elif array[3,1] < 20:
    resposta = 'O VALOR É MENOR QUE 20'
else:
    resposta = 'O VALOR NÃO É MAIOR OU IGUAL A 200'
resposta
# Out:
# 'O VALOR É MENOR QUE 20'

# %%
array[3,1]
# Out:
# np.float64(16.174283031423766)

# %%
if np.all(array > 0):
    print('Todos os valores são maiores que 0')
# Out:
# Todos os valores são maiores que 0

# %%
1 == 1
# Out:
# True

# %%
1 == 1 and 1 == 1
# Out:
# True

# %%
1 == 1 and 1 == 2
# Out:
# False

# %%
1 != False and 1 == 1
# Out:
# True

# %%
1 == 1 or 1 == 1
# Out:
# True

# %%
1 == 0 or 1 == 1
# Out:
# True

# %%
1 == 0 or 1 != 1
# Out:
# False

# %%
False and False and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or False or True
# Out:
# True

# %%
1 in [1, 2, 3]
# Out:
# True

# %%
'1' in [1, 2, 3]
# Out:
# False

# %%
'1' in '[1, 2, 3]'
# Out:
# True

# %%
p = 1
q = 1

p == q
# Out:
# True

# %%
p is q
# Out:
# True
